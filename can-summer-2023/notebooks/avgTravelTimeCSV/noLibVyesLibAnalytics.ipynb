# %%
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
plt.style.use('default')
import geopandas as gpd
import geodatasets
import ast
from shapely import wkt
import folium

# %%
libDems = pd.read_csv('../averageWalkingTimeNeighborhoodsNoLibIncluded.csv')

# %%
libDems.tail(3)
# Out:
#     Unnamed: 0                    Branch  \
# 79          79  Woodson Regional Library
# 80          80        Wrightwood-Ashburn
# 81          81      No Libs Neighborhood
#
#     Percent of People with Internet Access  \
# 79                                0.861885
# 80                                0.894687
# 81                                0.856951
#
#     Percent of People without Internet Access  \
# 79                                   0.138115
# 80                                   0.105313
# 81                                   0.133783
#
#     Percent of People with Computers  Percent of People without Computers  \
# 79                          0.908478                             0.091522
# 80                          0.944234                             0.055766
# 81                          0.898144                             0.092591
#
#     Percent of People with Computers and Internet  \
# 79                                       0.823103
# 80                                       0.869694
# 81                                       0.830901
#
#     Percent Population in Labor Force 16+: Employed  \
# 79                                         0.847484
# 80                                         0.896698
# 81                                         0.923222
#
#     Percent Population in Labor Force 16+: Unemployed  \
# 79                                           0.152516
# 80                                           0.103302
# 81                                           0.076778
#
#     Percent Households: Less Than $10,000  ...  Percent: 75 to 79 years  \
# 79                               0.092865  ...                 0.025893
# 80                               0.070531  ...                 0.028922
# 81                               0.071969  ...                 0.023903
#
#     Percent: 80 to 84 years  Percent: 85 years and over  \
# 79                 0.030445                    0.039622
# 80                 0.012624                    0.016501
# 81                 0.016903                    0.020090
#
#     Percent: 25+ Less Than High School  Percent: 25+ High School or More  \
# 79                            0.111294                          0.888706
# 80                            0.115282                          0.884718
# 81                            0.158664                          0.841336
#
#     Percent: 25+ Some College or More  Percent: 25+ Bachelor's Degree or More  \
# 79                           0.623501                                0.256464
# 80                           0.616149                                0.259722
# 81                           0.562588                                0.269537
#
#     Percent: 25+ Master's Degree or More  \
# 79                              0.103263
# 80                              0.100758
# 81                              0.099346
#
#     Percent: 25+ Professional School Degree or More  \
# 79                                         0.010696
# 80                                         0.017647
# 81                                         0.024139
#
#     Percent: 25+ Doctorate Degree
# 79                       0.006081
# 80                       0.008545
# 81                       0.007536
#
# [3 rows x 79 columns]

# %%
libDems = libDems.drop(columns = ['Unnamed: 0'])

# %%
libDems.tail(3)
# Out:
#                       Branch  Percent of People with Internet Access  \
# 79  Woodson Regional Library                                0.861885
# 80        Wrightwood-Ashburn                                0.894687
# 81      No Libs Neighborhood                                0.856951
#
#     Percent of People without Internet Access  \
# 79                                   0.138115
# 80                                   0.105313
# 81                                   0.133783
#
#     Percent of People with Computers  Percent of People without Computers  \
# 79                          0.908478                             0.091522
# 80                          0.944234                             0.055766
# 81                          0.898144                             0.092591
#
#     Percent of People with Computers and Internet  \
# 79                                       0.823103
# 80                                       0.869694
# 81                                       0.830901
#
#     Percent Population in Labor Force 16+: Employed  \
# 79                                         0.847484
# 80                                         0.896698
# 81                                         0.923222
#
#     Percent Population in Labor Force 16+: Unemployed  \
# 79                                           0.152516
# 80                                           0.103302
# 81                                           0.076778
#
#     Percent Households: Less Than $10,000  \
# 79                               0.092865
# 80                               0.070531
# 81                               0.071969
#
#     Percent Households: $10,000 to $14,999  ...  Percent: 75 to 79 years  \
# 79                                0.055883  ...                 0.025893
# 80                                0.021753  ...                 0.028922
# 81                                0.035886  ...                 0.023903
#
#     Percent: 80 to 84 years  Percent: 85 years and over  \
# 79                 0.030445                    0.039622
# 80                 0.012624                    0.016501
# 81                 0.016903                    0.020090
#
#     Percent: 25+ Less Than High School  Percent: 25+ High School or More  \
# 79                            0.111294                          0.888706
# 80                            0.115282                          0.884718
# 81                            0.158664                          0.841336
#
#     Percent: 25+ Some College or More  Percent: 25+ Bachelor's Degree or More  \
# 79                           0.623501                                0.256464
# 80                           0.616149                                0.259722
# 81                           0.562588                                0.269537
#
#     Percent: 25+ Master's Degree or More  \
# 79                              0.103263
# 80                              0.100758
# 81                              0.099346
#
#     Percent: 25+ Professional School Degree or More  \
# 79                                         0.010696
# 80                                         0.017647
# 81                                         0.024139
#
#     Percent: 25+ Doctorate Degree
# 79                       0.006081
# 80                       0.008545
# 81                       0.007536
#
# [3 rows x 78 columns]

# %%
noLibs = libDems.loc[[81]]

# %%
noLibs
# Out:
#                   Branch  Percent of People with Internet Access  \
# 81  No Libs Neighborhood                                0.856951
#
#     Percent of People without Internet Access  \
# 81                                   0.133783
#
#     Percent of People with Computers  Percent of People without Computers  \
# 81                          0.898144                             0.092591
#
#     Percent of People with Computers and Internet  \
# 81                                       0.830901
#
#     Percent Population in Labor Force 16+: Employed  \
# 81                                         0.923222
#
#     Percent Population in Labor Force 16+: Unemployed  \
# 81                                           0.076778
#
#     Percent Households: Less Than $10,000  \
# 81                               0.071969
#
#     Percent Households: $10,000 to $14,999  ...  Percent: 75 to 79 years  \
# 81                                0.035886  ...                 0.023903
#
#     Percent: 80 to 84 years  Percent: 85 years and over  \
# 81                 0.016903                     0.02009
#
#     Percent: 25+ Less Than High School  Percent: 25+ High School or More  \
# 81                            0.158664                          0.841336
#
#     Percent: 25+ Some College or More  Percent: 25+ Bachelor's Degree or More  \
# 81                           0.562588                                0.269537
#
#     Percent: 25+ Master's Degree or More  \
# 81                              0.099346
#
#     Percent: 25+ Professional School Degree or More  \
# 81                                         0.024139
#
#     Percent: 25+ Doctorate Degree
# 81                       0.007536
#
# [1 rows x 78 columns]

# %%
libDems = libDems.drop(index=libDems.index[81], axis=0)

# %%
libDems = libDems.set_index('Branch')

# %%
libDems.columns
# Out:
# Index(['Percent of People with Internet Access',
#        'Percent of People without Internet Access',
#        'Percent of People with Computers',
#        'Percent of People without Computers',
#        'Percent of People with Computers and Internet',
#        'Percent Population in Labor Force 16+: Employed',
#        'Percent Population in Labor Force 16+: Unemployed',
#        'Percent Households: Less Than $10,000',
#        'Percent Households: $10,000 to $14,999',
#        'Percent Households: $15,000 to $19,999',
#        'Percent Households: $20,000 to $24,999',
#        'Percent Households: $25,000 to $29,999',
#        'Percent Households: $30,000 to $34,999',
#        'Percent Households: $35,000 to $39,999',
#        'Percent Households: $40,000 to $44,999',
#        'Percent Households: $45,000 to $49,999',
#        'Percent Households: $50,000 to $59,999',
#        'Percent Households: $60,000 to $74,999',
#        'Percent Households: $75,000 to $99,999',
#        'Percent Households: $100,000 to $124,999',
#        'Percent Households: $125,000 to $149,999',
#        'Percent Households: $150,000 to $199,999',
#        'Percent Households: $200,000 or more',
#        'Percent Ages 18-64: Living in Poverty',
#        'Percent Ages 18-64: At or Above Poverty Level',
#        'Percent Households: With Public Assistance Income',
#        'Percent Households: No Public Assistance Income',
#        'Percent Owner and Renter Occupied Housing: No Vehicles',
#        'Percent Owner and Renter Occupied Housing: 1 Vehicle',
#        'Percent Owner and Renter Occupied Housing: 2 Vehicles',
#        'Percent Owner and Renter Occupied Housing: 3 Vehicles',
#        'Percent Owner and Renter Occupied Housing: 4 Vehicles',
#        'Percent Owner and Renter Occupied Housing: 5 or More Vehicles',
#        'Percent Renter-Occupied Housing: No Vehicles',
#        'Percent Renter-Occupied Housing: 1 Vehicle',
#        'Percent Renter-Occupied Housing: 2 Vehicles',
#        'Percent Renter-Occupied Housing: 3 Vehicles',
#        'Percent Renter-Occupied Housing: 4 Vehicles',
#        'Percent Renter-Occupied Housing: 5 or More Vehicles',
#        'Percent Workers 16+: Car, Truck, or Van ',
#        'Percent Workers 16+: Drove Alone', 'Percent Workers 16+: Carpooled',
#        'Percent Workers 16+: Public Transportation (Includes Taxi)',
#        'Percent Workers 16+: Motorcycle', 'Percent Workers 16+: Bicycle',
#        'Percent Workers 16+: Walked', 'Percent Workers 16+: Other Means',
#        'Percent: White Alone', 'Percent: Black or African American Alone',
#        'Percent: American Indian and Alaska Native Alone',
#        'Percent: Asian Alone',
#        'Percent: Native Hawaiian and Other Pacific Islander Alone',
#        'Percent: Some Other Race Alone', 'Percent: Two or More Races',
#        'Percent: under 5 years', 'Percent: 5 to 9 years',
#        'Percent: 10 to 14 years', 'Percent: 15 to 19 years',
#        'Percent: 20 to 24 years', 'Percent: 25 to 29 years',
#        'Percent: 30 to 34 years', 'Percent: 35 to 39 years',
#        'Percent: 50 to 54 years', 'Percent: 55 to 59 years',
#        'Percent: 60 to 64 years', 'Percent: 65 to 69 years',
#        'Percent: 70 to 74 years', 'Percent: 75 to 79 years',
#        'Percent: 80 to 84 years', 'Percent: 85 years and over',
#        'Percent: 25+ Less Than High School',
#        'Percent: 25+ High School or More', 'Percent: 25+ Some College or More',
#        'Percent: 25+ Bachelor's Degree or More',
#        'Percent: 25+ Master's Degree or More',
#        'Percent: 25+ Professional School Degree or More',
#        'Percent: 25+ Doctorate Degree'],
#       dtype='object')

# %%
avgLibDems = pd.DataFrame(columns = ['Percent of People with Internet Access',
       'Percent of People without Internet Access',
       'Percent of People with Computers',
       'Percent of People without Computers',
       'Percent of People with Computers and Internet',
       'Percent Population in Labor Force 16+: Employed',
       'Percent Population in Labor Force 16+: Unemployed',
       'Percent Households: Less Than $10,000',
       'Percent Households: $10,000 to $14,999',
       'Percent Households: $15,000 to $19,999',
       'Percent Households: $20,000 to $24,999',
       'Percent Households: $25,000 to $29,999',
       'Percent Households: $30,000 to $34,999',
       'Percent Households: $35,000 to $39,999',
       'Percent Households: $40,000 to $44,999',
       'Percent Households: $45,000 to $49,999',
       'Percent Households: $50,000 to $59,999',
       'Percent Households: $60,000 to $74,999',
       'Percent Households: $75,000 to $99,999',
       'Percent Households: $100,000 to $124,999',
       'Percent Households: $125,000 to $149,999',
       'Percent Households: $150,000 to $199,999',
       'Percent Households: $200,000 or more',
       'Percent Ages 18-64: Living in Poverty',
       'Percent Ages 18-64: At or Above Poverty Level',
       'Percent Households: With Public Assistance Income',
       'Percent Households: No Public Assistance Income',
       'Percent Owner and Renter Occupied Housing: No Vehicles',
       'Percent Owner and Renter Occupied Housing: 1 Vehicle',
       'Percent Owner and Renter Occupied Housing: 2 Vehicles',
       'Percent Owner and Renter Occupied Housing: 3 Vehicles',
       'Percent Owner and Renter Occupied Housing: 4 Vehicles',
       'Percent Owner and Renter Occupied Housing: 5 or More Vehicles',
       'Percent Renter-Occupied Housing: No Vehicles',
       'Percent Renter-Occupied Housing: 1 Vehicle',
       'Percent Renter-Occupied Housing: 2 Vehicles',
       'Percent Renter-Occupied Housing: 3 Vehicles',
       'Percent Renter-Occupied Housing: 4 Vehicles',
       'Percent Renter-Occupied Housing: 5 or More Vehicles',
       'Percent Workers 16+: Car, Truck, or Van ',
       'Percent Workers 16+: Drove Alone', 'Percent Workers 16+: Carpooled',
       'Percent Workers 16+: Public Transportation (Includes Taxi)',
       'Percent Workers 16+: Motorcycle', 'Percent Workers 16+: Bicycle',
       'Percent Workers 16+: Walked', 'Percent Workers 16+: Other Means',
       'Percent: White Alone', 'Percent: Black or African American Alone',
       'Percent: American Indian and Alaska Native Alone',
       'Percent: Asian Alone',
       'Percent: Native Hawaiian and Other Pacific Islander Alone',
       'Percent: Some Other Race Alone', 'Percent: Two or More Races',
       'Percent: under 5 years', 'Percent: 5 to 9 years',
       'Percent: 10 to 14 years', 'Percent: 15 to 19 years',
       'Percent: 20 to 24 years', 'Percent: 25 to 29 years',
       'Percent: 30 to 34 years', 'Percent: 35 to 39 years',
       'Percent: 50 to 54 years', 'Percent: 55 to 59 years',
       'Percent: 60 to 64 years', 'Percent: 65 to 69 years',
       'Percent: 70 to 74 years', 'Percent: 75 to 79 years',
       'Percent: 80 to 84 years', 'Percent: 85 years and over',
       'Percent: 25+ Less Than High School',
       'Percent: 25+ High School or More', 'Percent: 25+ Some College or More',
       "Percent: 25+ Bachelor's Degree or More",
       "Percent: 25+ Master's Degree or More",
       'Percent: 25+ Professional School Degree or More',
       'Percent: 25+ Doctorate Degree'])

# %%
libDems.loc['total']= libDems.sum()

# %%
libDems.loc['average']= libDems.loc['total']/81

# %%
libDems.tail(3)
# Out:
#                     Percent of People with Internet Access  \
# Branch
# Wrightwood-Ashburn                                0.894687
# total                                            69.075031
# average                                           0.852778
#
#                     Percent of People without Internet Access  \
# Branch
# Wrightwood-Ashburn                                   0.105313
# total                                               10.911765
# average                                              0.134713
#
#                     Percent of People with Computers  \
# Branch
# Wrightwood-Ashburn                          0.944234
# total                                      71.408325
# average                                     0.881584
#
#                     Percent of People without Computers  \
# Branch
# Wrightwood-Ashburn                             0.055766
# total                                          7.599450
# average                                        0.093820
#
#                     Percent of People with Computers and Internet  \
# Branch
# Wrightwood-Ashburn                                       0.869694
# total                                                   66.689538
# average                                                  0.823328
#
#                     Percent Population in Labor Force 16+: Employed  \
# Branch
# Wrightwood-Ashburn                                         0.896698
# total                                                     72.703991
# average                                                    0.897580
#
#                     Percent Population in Labor Force 16+: Unemployed  \
# Branch
# Wrightwood-Ashburn                                           0.103302
# total                                                        8.296009
# average                                                      0.102420
#
#                     Percent Households: Less Than $10,000  \
# Branch
# Wrightwood-Ashburn                               0.070531
# total                                            7.599063
# average                                          0.093816
#
#                     Percent Households: $10,000 to $14,999  \
# Branch
# Wrightwood-Ashburn                                0.021753
# total                                             4.022898
# average                                           0.049665
#
#                     Percent Households: $15,000 to $19,999  ...  \
# Branch                                                      ...
# Wrightwood-Ashburn                                0.027476  ...
# total                                             3.818726  ...
# average                                           0.047145  ...
#
#                     Percent: 75 to 79 years  Percent: 80 to 84 years  \
# Branch
# Wrightwood-Ashburn                 0.028922                 0.012624
# total                              1.873279                 1.190614
# average                            0.023127                 0.014699
#
#                     Percent: 85 years and over  \
# Branch
# Wrightwood-Ashburn                    0.016501
# total                                 1.352187
# average                               0.016694
#
#                     Percent: 25+ Less Than High School  \
# Branch
# Wrightwood-Ashburn                            0.115282
# total                                        11.808437
# average                                       0.145783
#
#                     Percent: 25+ High School or More  \
# Branch
# Wrightwood-Ashburn                          0.884718
# total                                      69.191563
# average                                     0.854217
#
#                     Percent: 25+ Some College or More  \
# Branch
# Wrightwood-Ashburn                           0.616149
# total                                       49.632681
# average                                      0.612749
#
#                     Percent: 25+ Bachelor's Degree or More  \
# Branch
# Wrightwood-Ashburn                                0.259722
# total                                            29.593122
# average                                           0.365347
#
#                     Percent: 25+ Master's Degree or More  \
# Branch
# Wrightwood-Ashburn                              0.100758
# total                                          12.385735
# average                                         0.152910
#
#                     Percent: 25+ Professional School Degree or More  \
# Branch
# Wrightwood-Ashburn                                         0.017647
# total                                                      3.684098
# average                                                    0.045483
#
#                     Percent: 25+ Doctorate Degree
# Branch
# Wrightwood-Ashburn                       0.008545
# total                                    1.316029
# average                                  0.016247
#
# [3 rows x 77 columns]

# %%
libDems.loc['no library'] = noLibs.iloc[0]

# %%
libDems.tail(3)
# Out:
#             Percent of People with Internet Access  \
# Branch
# total                                    69.075031
# average                                   0.852778
# no library                                0.856951
#
#             Percent of People without Internet Access  \
# Branch
# total                                       10.911765
# average                                      0.134713
# no library                                   0.133783
#
#             Percent of People with Computers  \
# Branch
# total                              71.408325
# average                             0.881584
# no library                          0.898144
#
#             Percent of People without Computers  \
# Branch
# total                                  7.599450
# average                                0.093820
# no library                             0.092591
#
#             Percent of People with Computers and Internet  \
# Branch
# total                                           66.689538
# average                                          0.823328
# no library                                       0.830901
#
#             Percent Population in Labor Force 16+: Employed  \
# Branch
# total                                             72.703991
# average                                            0.897580
# no library                                         0.923222
#
#             Percent Population in Labor Force 16+: Unemployed  \
# Branch
# total                                                8.296009
# average                                              0.102420
# no library                                           0.076778
#
#             Percent Households: Less Than $10,000  \
# Branch
# total                                    7.599063
# average                                  0.093816
# no library                               0.071969
#
#             Percent Households: $10,000 to $14,999  \
# Branch
# total                                     4.022898
# average                                   0.049665
# no library                                0.035886
#
#             Percent Households: $15,000 to $19,999  ...  \
# Branch                                              ...
# total                                     3.818726  ...
# average                                   0.047145  ...
# no library                                0.042092  ...
#
#             Percent: 75 to 79 years  Percent: 80 to 84 years  \
# Branch
# total                      1.873279                 1.190614
# average                    0.023127                 0.014699
# no library                 0.023903                 0.016903
#
#             Percent: 85 years and over  Percent: 25+ Less Than High School  \
# Branch
# total                         1.352187                           11.808437
# average                       0.016694                            0.145783
# no library                    0.020090                            0.158664
#
#             Percent: 25+ High School or More  \
# Branch
# total                              69.191563
# average                             0.854217
# no library                          0.841336
#
#             Percent: 25+ Some College or More  \
# Branch
# total                               49.632681
# average                              0.612749
# no library                           0.562588
#
#             Percent: 25+ Bachelor's Degree or More  \
# Branch
# total                                    29.593122
# average                                   0.365347
# no library                                0.269537
#
#             Percent: 25+ Master's Degree or More  \
# Branch
# total                                  12.385735
# average                                 0.152910
# no library                              0.099346
#
#             Percent: 25+ Professional School Degree or More  \
# Branch
# total                                              3.684098
# average                                            0.045483
# no library                                         0.024139
#
#             Percent: 25+ Doctorate Degree
# Branch
# total                            1.316029
# average                          0.016247
# no library                       0.007536
#
# [3 rows x 77 columns]

# %%
libDems.loc['avg minus no library'] = libDems.loc['average']-libDems.loc['no library']

# %%
libDems.tail(3)
# Out:
#                       Percent of People with Internet Access  \
# Branch
# average                                             0.852778
# no library                                          0.856951
# avg minus no library                               -0.004173
#
#                       Percent of People without Internet Access  \
# Branch
# average                                                0.134713
# no library                                             0.133783
# avg minus no library                                   0.000930
#
#                       Percent of People with Computers  \
# Branch
# average                                       0.881584
# no library                                    0.898144
# avg minus no library                         -0.016560
#
#                       Percent of People without Computers  \
# Branch
# average                                          0.093820
# no library                                       0.092591
# avg minus no library                             0.001230
#
#                       Percent of People with Computers and Internet  \
# Branch
# average                                                    0.823328
# no library                                                 0.830901
# avg minus no library                                      -0.007573
#
#                       Percent Population in Labor Force 16+: Employed  \
# Branch
# average                                                      0.897580
# no library                                                   0.923222
# avg minus no library                                        -0.025642
#
#                       Percent Population in Labor Force 16+: Unemployed  \
# Branch
# average                                                        0.102420
# no library                                                     0.076778
# avg minus no library                                           0.025642
#
#                       Percent Households: Less Than $10,000  \
# Branch
# average                                            0.093816
# no library                                         0.071969
# avg minus no library                               0.021847
#
#                       Percent Households: $10,000 to $14,999  \
# Branch
# average                                             0.049665
# no library                                          0.035886
# avg minus no library                                0.013779
#
#                       Percent Households: $15,000 to $19,999  ...  \
# Branch                                                        ...
# average                                             0.047145  ...
# no library                                          0.042092  ...
# avg minus no library                                0.005053  ...
#
#                       Percent: 75 to 79 years  Percent: 80 to 84 years  \
# Branch
# average                              0.023127                 0.014699
# no library                           0.023903                 0.016903
# avg minus no library                -0.000776                -0.002204
#
#                       Percent: 85 years and over  \
# Branch
# average                                 0.016694
# no library                              0.020090
# avg minus no library                   -0.003396
#
#                       Percent: 25+ Less Than High School  \
# Branch
# average                                         0.145783
# no library                                      0.158664
# avg minus no library                           -0.012881
#
#                       Percent: 25+ High School or More  \
# Branch
# average                                       0.854217
# no library                                    0.841336
# avg minus no library                          0.012881
#
#                       Percent: 25+ Some College or More  \
# Branch
# average                                        0.612749
# no library                                     0.562588
# avg minus no library                           0.050161
#
#                       Percent: 25+ Bachelor's Degree or More  \
# Branch
# average                                             0.365347
# no library                                          0.269537
# avg minus no library                                0.095810
#
#                       Percent: 25+ Master's Degree or More  \
# Branch
# average                                           0.152910
# no library                                        0.099346
# avg minus no library                              0.053564
#
#                       Percent: 25+ Professional School Degree or More  \
# Branch
# average                                                      0.045483
# no library                                                   0.024139
# avg minus no library                                         0.021343
#
#                       Percent: 25+ Doctorate Degree
# Branch
# average                                    0.016247
# no library                                 0.007536
# avg minus no library                       0.008711
#
# [3 rows x 77 columns]

# %%
libDems = libDems.reset_index()

# %%
libDems.tail(3)
# Out:
#                   Branch  Percent of People with Internet Access  \
# 82               average                                0.852778
# 83            no library                                0.856951
# 84  avg minus no library                               -0.004173
#
#     Percent of People without Internet Access  \
# 82                                   0.134713
# 83                                   0.133783
# 84                                   0.000930
#
#     Percent of People with Computers  Percent of People without Computers  \
# 82                          0.881584                             0.093820
# 83                          0.898144                             0.092591
# 84                         -0.016560                             0.001230
#
#     Percent of People with Computers and Internet  \
# 82                                       0.823328
# 83                                       0.830901
# 84                                      -0.007573
#
#     Percent Population in Labor Force 16+: Employed  \
# 82                                         0.897580
# 83                                         0.923222
# 84                                        -0.025642
#
#     Percent Population in Labor Force 16+: Unemployed  \
# 82                                           0.102420
# 83                                           0.076778
# 84                                           0.025642
#
#     Percent Households: Less Than $10,000  \
# 82                               0.093816
# 83                               0.071969
# 84                               0.021847
#
#     Percent Households: $10,000 to $14,999  ...  Percent: 75 to 79 years  \
# 82                                0.049665  ...                 0.023127
# 83                                0.035886  ...                 0.023903
# 84                                0.013779  ...                -0.000776
#
#     Percent: 80 to 84 years  Percent: 85 years and over  \
# 82                 0.014699                    0.016694
# 83                 0.016903                    0.020090
# 84                -0.002204                   -0.003396
#
#     Percent: 25+ Less Than High School  Percent: 25+ High School or More  \
# 82                            0.145783                          0.854217
# 83                            0.158664                          0.841336
# 84                           -0.012881                          0.012881
#
#     Percent: 25+ Some College or More  Percent: 25+ Bachelor's Degree or More  \
# 82                           0.612749                                0.365347
# 83                           0.562588                                0.269537
# 84                           0.050161                                0.095810
#
#     Percent: 25+ Master's Degree or More  \
# 82                              0.152910
# 83                              0.099346
# 84                              0.053564
#
#     Percent: 25+ Professional School Degree or More  \
# 82                                         0.045483
# 83                                         0.024139
# 84                                         0.021343
#
#     Percent: 25+ Doctorate Degree
# 82                       0.016247
# 83                       0.007536
# 84                       0.008711
#
# [3 rows x 78 columns]

# %%
libDems = libDems.iloc[82:85]

# %%
libDems
# Out:
#                   Branch  Percent of People with Internet Access  \
# 82               average                                0.852778
# 83            no library                                0.856951
# 84  avg minus no library                               -0.004173
#
#     Percent of People without Internet Access  \
# 82                                   0.134713
# 83                                   0.133783
# 84                                   0.000930
#
#     Percent of People with Computers  Percent of People without Computers  \
# 82                          0.881584                             0.093820
# 83                          0.898144                             0.092591
# 84                         -0.016560                             0.001230
#
#     Percent of People with Computers and Internet  \
# 82                                       0.823328
# 83                                       0.830901
# 84                                      -0.007573
#
#     Percent Population in Labor Force 16+: Employed  \
# 82                                         0.897580
# 83                                         0.923222
# 84                                        -0.025642
#
#     Percent Population in Labor Force 16+: Unemployed  \
# 82                                           0.102420
# 83                                           0.076778
# 84                                           0.025642
#
#     Percent Households: Less Than $10,000  \
# 82                               0.093816
# 83                               0.071969
# 84                               0.021847
#
#     Percent Households: $10,000 to $14,999  ...  Percent: 75 to 79 years  \
# 82                                0.049665  ...                 0.023127
# 83                                0.035886  ...                 0.023903
# 84                                0.013779  ...                -0.000776
#
#     Percent: 80 to 84 years  Percent: 85 years and over  \
# 82                 0.014699                    0.016694
# 83                 0.016903                    0.020090
# 84                -0.002204                   -0.003396
#
#     Percent: 25+ Less Than High School  Percent: 25+ High School or More  \
# 82                            0.145783                          0.854217
# 83                            0.158664                          0.841336
# 84                           -0.012881                          0.012881
#
#     Percent: 25+ Some College or More  Percent: 25+ Bachelor's Degree or More  \
# 82                           0.612749                                0.365347
# 83                           0.562588                                0.269537
# 84                           0.050161                                0.095810
#
#     Percent: 25+ Master's Degree or More  \
# 82                              0.152910
# 83                              0.099346
# 84                              0.053564
#
#     Percent: 25+ Professional School Degree or More  \
# 82                                         0.045483
# 83                                         0.024139
# 84                                         0.021343
#
#     Percent: 25+ Doctorate Degree
# 82                       0.016247
# 83                       0.007536
# 84                       0.008711
#
# [3 rows x 78 columns]

# %%
libDems.to_csv('../comparisonsAverageWalkingTime.csv')
